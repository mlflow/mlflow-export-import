# %%
experiment_id_or_name="dev_taxi_fare_train_dev"
output_dir="output"

# %%
import os
from dotenv import load_dotenv
from mlflow_export_import.client import client_utils
from mlflow_export_import.common import mlflow_utils
from mlflow_export_import.experiment.export_experiment import export_experiment


mlflow_tracking_uri = os.getenv("MLFLOW_TRACKING_URI")
mlflow_client = client_utils.create_mlflow_client_from_tracking_uri(mlflow_tracking_uri)
experiment = mlflow_utils.get_experiment(mlflow_client, experiment_id_or_name)
output_dir = f"{output_dir}/{experiment.experiment_id}"

run_start_date=None
export_permissions=None
notebook_formats=None

print("experiment_id:", experiment.experiment_id)
print("experiment_name:", experiment.name)       
print("output_dir:", output_dir)
# Out:
# 11-Jul-24 15:20:49 - DEBUG - EnvironmentCredential.get_token failed: EnvironmentCredential authentication unavailable. Environment variables are not fully configured.
# Visit https://aka.ms/azsdk/python/identity/environmentcredential/troubleshoot to troubleshoot this issue.
# Traceback (most recent call last):
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\decorators.py", line 33, in wrapper
#     token = fn(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_credentials\environment.py", line 156, in get_token
#     raise CredentialUnavailableError(message=message)
# azure.identity._exceptions.CredentialUnavailableError: EnvironmentCredential authentication unavailable. Environment variables are not fully configured.
# Visit https://aka.ms/azsdk/python/identity/environmentcredential/troubleshoot to troubleshoot this issue.
# 11-Jul-24 15:20:49 - INFO - Request URL: 'http://169.254.169.254/metadata/identity/oauth2/token?api-version=REDACTED&resource=REDACTED'
# Request method: 'GET'
# Request headers:
#     'User-Agent': 'azsdk-python-identity/1.17.1 Python/3.11.9 (Windows-10-10.0.22631-SP0)'
# No body was attached to the request
# 11-Jul-24 15:20:49 - DEBUG - ImdsCredential.get_token failed: ManagedIdentityCredential authentication unavailable, no response from the IMDS endpoint.
# Traceback (most recent call last):
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_credentials\imds.py", line 88, in _request_token
#     self._client.request_token(*scopes, connection_timeout=1, retry_total=0)
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\managed_identity_client.py", line 131, in request_token
#     response = self._pipeline.run(request, retry_on_methods=[request.method], **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 229, in run
#     return first_node.send(pipeline_request)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   [Previous line repeated 1 more time]
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\policies\_retry.py", line 554, in send
#     raise err
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\policies\_retry.py", line 532, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   [Previous line repeated 1 more time]
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 118, in send
#     self._sender.send(request.http_request, **request.context.options),
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\transport\_requests_basic.py", line 401, in send
#     raise error
# azure.core.exceptions.ServiceRequestError: <urllib3.connection.HTTPConnection object at 0x000002A215EFC250>: Failed to establish a new connection: [WinError 10051] A socket operation was attempted to an unreachable network
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\get_token_mixin.py", line 93, in get_token
#     token = self._request_token(
#             ^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_credentials\imds.py", line 98, in _request_token
#     raise CredentialUnavailableError(error_message) from ex
# azure.identity._exceptions.CredentialUnavailableError: ManagedIdentityCredential authentication unavailable, no response from the IMDS endpoint.
# 11-Jul-24 15:20:49 - DEBUG - ManagedIdentityCredential.get_token failed: ManagedIdentityCredential authentication unavailable, no response from the IMDS endpoint.
# Traceback (most recent call last):
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_credentials\imds.py", line 88, in _request_token
#     self._client.request_token(*scopes, connection_timeout=1, retry_total=0)
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\managed_identity_client.py", line 131, in request_token
#     response = self._pipeline.run(request, retry_on_methods=[request.method], **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 229, in run
#     return first_node.send(pipeline_request)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   [Previous line repeated 1 more time]
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\policies\_retry.py", line 554, in send
#     raise err
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\policies\_retry.py", line 532, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   [Previous line repeated 1 more time]
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 118, in send
#     self._sender.send(request.http_request, **request.context.options),
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\transport\_requests_basic.py", line 401, in send
#     raise error
# azure.core.exceptions.ServiceRequestError: <urllib3.connection.HTTPConnection object at 0x000002A215EFC250>: Failed to establish a new connection: [WinError 10051] A socket operation was attempted to an unreachable network
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\decorators.py", line 33, in wrapper
#     token = fn(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_credentials\managed_identity.py", line 139, in get_token
#     return self._credential.get_token(*scopes, claims=claims, tenant_id=tenant_id, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\get_token_mixin.py", line 93, in get_token
#     token = self._request_token(
#             ^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_credentials\imds.py", line 98, in _request_token
#     raise CredentialUnavailableError(error_message) from ex
# azure.identity._exceptions.CredentialUnavailableError: ManagedIdentityCredential authentication unavailable, no response from the IMDS endpoint.
# 11-Jul-24 15:20:49 - DEBUG - SharedTokenCacheCredential.get_token failed: SharedTokenCacheCredential authentication unavailable. No accounts were found in the cache.
# Traceback (most recent call last):
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\decorators.py", line 33, in wrapper
#     token = fn(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_credentials\shared_cache.py", line 88, in get_token
#     return self._credential.get_token(*scopes, claims=claims, tenant_id=tenant_id, enable_cae=enable_cae, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_credentials\shared_cache.py", line 137, in get_token
#     account = self._get_account(self._username, self._tenant_id, is_cae=is_cae)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\decorators.py", line 79, in wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\shared_token_cache.py", line 205, in _get_account
#     raise CredentialUnavailableError(message=NO_ACCOUNTS)
# azure.identity._exceptions.CredentialUnavailableError: SharedTokenCacheCredential authentication unavailable. No accounts were found in the cache.
# 11-Jul-24 15:20:51 - DEBUG - AzureCliCredential.get_token succeeded
# 11-Jul-24 15:20:51 - DEBUG - [Authenticated account] Client ID: 04b07795-8ddb-461a-bbee-02f9e1bf7b46. Tenant ID: 16b3c013-d300-468d-ac64-7eda0820b6d3. User Principal Name: unavailableUpn. Object ID (user): 1e19e3c5-a350-402a-9194-1f1b3633259b
# 11-Jul-24 15:20:51 - INFO - ChainedTokenCredential acquired a token from AzureCliCredential
# experiment_id: b64be052-5810-4b0f-b345-c70f81b8284f
# experiment_name: dev_taxi_fare_train_dev
# output_dir: output/b64be052-5810-4b0f-b345-c70f81b8284f/b64be052-5810-4b0f-b345-c70f81b8284f/b64be052-5810-4b0f-b345-c70f81b8284f

# %%
export_experiment(
    experiment_id_or_name = experiment.experiment_id,
    output_dir = output_dir,
    run_start_time = run_start_date,
    export_permissions = export_permissions,
    notebook_formats = notebook_formats
)
# Out:
# 11-Jul-24 15:20:56 - DEBUG - EnvironmentCredential.get_token failed: EnvironmentCredential authentication unavailable. Environment variables are not fully configured.
# Visit https://aka.ms/azsdk/python/identity/environmentcredential/troubleshoot to troubleshoot this issue.
# Traceback (most recent call last):
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\decorators.py", line 33, in wrapper
#     token = fn(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_credentials\environment.py", line 156, in get_token
#     raise CredentialUnavailableError(message=message)
# azure.identity._exceptions.CredentialUnavailableError: EnvironmentCredential authentication unavailable. Environment variables are not fully configured.
# Visit https://aka.ms/azsdk/python/identity/environmentcredential/troubleshoot to troubleshoot this issue.
# 11-Jul-24 15:20:56 - INFO - Request URL: 'http://169.254.169.254/metadata/identity/oauth2/token?api-version=REDACTED&resource=REDACTED'
# Request method: 'GET'
# Request headers:
#     'User-Agent': 'azsdk-python-identity/1.17.1 Python/3.11.9 (Windows-10-10.0.22631-SP0)'
# No body was attached to the request
# 11-Jul-24 15:20:56 - DEBUG - ImdsCredential.get_token failed: ManagedIdentityCredential authentication unavailable, no response from the IMDS endpoint.
# Traceback (most recent call last):
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_credentials\imds.py", line 88, in _request_token
#     self._client.request_token(*scopes, connection_timeout=1, retry_total=0)
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\managed_identity_client.py", line 131, in request_token
#     response = self._pipeline.run(request, retry_on_methods=[request.method], **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 229, in run
#     return first_node.send(pipeline_request)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   [Previous line repeated 1 more time]
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\policies\_retry.py", line 554, in send
#     raise err
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\policies\_retry.py", line 532, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   [Previous line repeated 1 more time]
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 118, in send
#     self._sender.send(request.http_request, **request.context.options),
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\transport\_requests_basic.py", line 401, in send
#     raise error
# azure.core.exceptions.ServiceRequestError: <urllib3.connection.HTTPConnection object at 0x000002A215EFE850>: Failed to establish a new connection: [WinError 10051] A socket operation was attempted to an unreachable network
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\get_token_mixin.py", line 93, in get_token
#     token = self._request_token(
#             ^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_credentials\imds.py", line 98, in _request_token
#     raise CredentialUnavailableError(error_message) from ex
# azure.identity._exceptions.CredentialUnavailableError: ManagedIdentityCredential authentication unavailable, no response from the IMDS endpoint.
# 11-Jul-24 15:20:56 - DEBUG - ManagedIdentityCredential.get_token failed: ManagedIdentityCredential authentication unavailable, no response from the IMDS endpoint.
# Traceback (most recent call last):
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_credentials\imds.py", line 88, in _request_token
#     self._client.request_token(*scopes, connection_timeout=1, retry_total=0)
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\managed_identity_client.py", line 131, in request_token
#     response = self._pipeline.run(request, retry_on_methods=[request.method], **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 229, in run
#     return first_node.send(pipeline_request)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   [Previous line repeated 1 more time]
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\policies\_retry.py", line 554, in send
#     raise err
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\policies\_retry.py", line 532, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   [Previous line repeated 1 more time]
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 118, in send
#     self._sender.send(request.http_request, **request.context.options),
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\transport\_requests_basic.py", line 401, in send
#     raise error
# azure.core.exceptions.ServiceRequestError: <urllib3.connection.HTTPConnection object at 0x000002A215EFE850>: Failed to establish a new connection: [WinError 10051] A socket operation was attempted to an unreachable network
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\decorators.py", line 33, in wrapper
#     token = fn(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_credentials\managed_identity.py", line 139, in get_token
#     return self._credential.get_token(*scopes, claims=claims, tenant_id=tenant_id, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\get_token_mixin.py", line 93, in get_token
#     token = self._request_token(
#             ^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_credentials\imds.py", line 98, in _request_token
#     raise CredentialUnavailableError(error_message) from ex
# azure.identity._exceptions.CredentialUnavailableError: ManagedIdentityCredential authentication unavailable, no response from the IMDS endpoint.
# 11-Jul-24 15:20:56 - DEBUG - SharedTokenCacheCredential.get_token failed: SharedTokenCacheCredential authentication unavailable. No accounts were found in the cache.
# Traceback (most recent call last):
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\decorators.py", line 33, in wrapper
#     token = fn(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_credentials\shared_cache.py", line 88, in get_token
#     return self._credential.get_token(*scopes, claims=claims, tenant_id=tenant_id, enable_cae=enable_cae, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_credentials\shared_cache.py", line 137, in get_token
#     account = self._get_account(self._username, self._tenant_id, is_cae=is_cae)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\decorators.py", line 79, in wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\shared_token_cache.py", line 205, in _get_account
#     raise CredentialUnavailableError(message=NO_ACCOUNTS)
# azure.identity._exceptions.CredentialUnavailableError: SharedTokenCacheCredential authentication unavailable. No accounts were found in the cache.
# 11-Jul-24 15:20:58 - DEBUG - AzureCliCredential.get_token succeeded
# 11-Jul-24 15:20:58 - DEBUG - [Authenticated account] Client ID: 04b07795-8ddb-461a-bbee-02f9e1bf7b46. Tenant ID: 16b3c013-d300-468d-ac64-7eda0820b6d3. User Principal Name: unavailableUpn. Object ID (user): 1e19e3c5-a350-402a-9194-1f1b3633259b
# 11-Jul-24 15:20:58 - INFO - ChainedTokenCredential acquired a token from AzureCliCredential
# 11-Jul-24 15:20:58 - DEBUG - EnvironmentCredential.get_token failed: EnvironmentCredential authentication unavailable. Environment variables are not fully configured.
# Visit https://aka.ms/azsdk/python/identity/environmentcredential/troubleshoot to troubleshoot this issue.
# Traceback (most recent call last):
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\decorators.py", line 33, in wrapper
#     token = fn(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_credentials\environment.py", line 156, in get_token
#     raise CredentialUnavailableError(message=message)
# azure.identity._exceptions.CredentialUnavailableError: EnvironmentCredential authentication unavailable. Environment variables are not fully configured.
# Visit https://aka.ms/azsdk/python/identity/environmentcredential/troubleshoot to troubleshoot this issue.
# 11-Jul-24 15:20:58 - INFO - Request URL: 'http://169.254.169.254/metadata/identity/oauth2/token?api-version=REDACTED&resource=REDACTED'
# Request method: 'GET'
# Request headers:
#     'User-Agent': 'azsdk-python-identity/1.17.1 Python/3.11.9 (Windows-10-10.0.22631-SP0)'
# No body was attached to the request
# 11-Jul-24 15:20:58 - DEBUG - ImdsCredential.get_token failed: ManagedIdentityCredential authentication unavailable, no response from the IMDS endpoint.
# Traceback (most recent call last):
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_credentials\imds.py", line 88, in _request_token
#     self._client.request_token(*scopes, connection_timeout=1, retry_total=0)
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\managed_identity_client.py", line 131, in request_token
#     response = self._pipeline.run(request, retry_on_methods=[request.method], **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 229, in run
#     return first_node.send(pipeline_request)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   [Previous line repeated 1 more time]
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\policies\_retry.py", line 554, in send
#     raise err
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\policies\_retry.py", line 532, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   [Previous line repeated 1 more time]
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 118, in send
#     self._sender.send(request.http_request, **request.context.options),
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\transport\_requests_basic.py", line 401, in send
#     raise error
# azure.core.exceptions.ServiceRequestError: <urllib3.connection.HTTPConnection object at 0x000002A215EC8A50>: Failed to establish a new connection: [WinError 10051] A socket operation was attempted to an unreachable network
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\get_token_mixin.py", line 93, in get_token
#     token = self._request_token(
#             ^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_credentials\imds.py", line 98, in _request_token
#     raise CredentialUnavailableError(error_message) from ex
# azure.identity._exceptions.CredentialUnavailableError: ManagedIdentityCredential authentication unavailable, no response from the IMDS endpoint.
# 11-Jul-24 15:20:58 - DEBUG - ManagedIdentityCredential.get_token failed: ManagedIdentityCredential authentication unavailable, no response from the IMDS endpoint.
# Traceback (most recent call last):
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_credentials\imds.py", line 88, in _request_token
#     self._client.request_token(*scopes, connection_timeout=1, retry_total=0)
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\managed_identity_client.py", line 131, in request_token
#     response = self._pipeline.run(request, retry_on_methods=[request.method], **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 229, in run
#     return first_node.send(pipeline_request)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   [Previous line repeated 1 more time]
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\policies\_retry.py", line 554, in send
#     raise err
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\policies\_retry.py", line 532, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   [Previous line repeated 1 more time]
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 118, in send
#     self._sender.send(request.http_request, **request.context.options),
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\transport\_requests_basic.py", line 401, in send
#     raise error
# azure.core.exceptions.ServiceRequestError: <urllib3.connection.HTTPConnection object at 0x000002A215EC8A50>: Failed to establish a new connection: [WinError 10051] A socket operation was attempted to an unreachable network
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\decorators.py", line 33, in wrapper
#     token = fn(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_credentials\managed_identity.py", line 139, in get_token
#     return self._credential.get_token(*scopes, claims=claims, tenant_id=tenant_id, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\get_token_mixin.py", line 93, in get_token
#     token = self._request_token(
#             ^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_credentials\imds.py", line 98, in _request_token
#     raise CredentialUnavailableError(error_message) from ex
# azure.identity._exceptions.CredentialUnavailableError: ManagedIdentityCredential authentication unavailable, no response from the IMDS endpoint.
# 11-Jul-24 15:20:58 - DEBUG - SharedTokenCacheCredential.get_token failed: SharedTokenCacheCredential authentication unavailable. No accounts were found in the cache.
# Traceback (most recent call last):
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\decorators.py", line 33, in wrapper
#     token = fn(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_credentials\shared_cache.py", line 88, in get_token
#     return self._credential.get_token(*scopes, claims=claims, tenant_id=tenant_id, enable_cae=enable_cae, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_credentials\shared_cache.py", line 137, in get_token
#     account = self._get_account(self._username, self._tenant_id, is_cae=is_cae)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\decorators.py", line 79, in wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\shared_token_cache.py", line 205, in _get_account
#     raise CredentialUnavailableError(message=NO_ACCOUNTS)
# azure.identity._exceptions.CredentialUnavailableError: SharedTokenCacheCredential authentication unavailable. No accounts were found in the cache.
# 11-Jul-24 15:21:01 - DEBUG - AzureCliCredential.get_token succeeded
# 11-Jul-24 15:21:01 - DEBUG - [Authenticated account] Client ID: 04b07795-8ddb-461a-bbee-02f9e1bf7b46. Tenant ID: 16b3c013-d300-468d-ac64-7eda0820b6d3. User Principal Name: unavailableUpn. Object ID (user): 1e19e3c5-a350-402a-9194-1f1b3633259b
# 11-Jul-24 15:21:01 - INFO - ChainedTokenCredential acquired a token from AzureCliCredential
# 11-Jul-24 15:21:01 - INFO - Exporting experiment: {'name': 'dev_taxi_fare_train_dev', 'id': 'b64be052-5810-4b0f-b345-c70f81b8284f', 'mlflow.experimentType': None, 'lifecycle_stage': 'active'}
# 11-Jul-24 15:21:01 - DEBUG - EnvironmentCredential.get_token failed: EnvironmentCredential authentication unavailable. Environment variables are not fully configured.
# Visit https://aka.ms/azsdk/python/identity/environmentcredential/troubleshoot to troubleshoot this issue.
# Traceback (most recent call last):
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\decorators.py", line 33, in wrapper
#     token = fn(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_credentials\environment.py", line 156, in get_token
#     raise CredentialUnavailableError(message=message)
# azure.identity._exceptions.CredentialUnavailableError: EnvironmentCredential authentication unavailable. Environment variables are not fully configured.
# Visit https://aka.ms/azsdk/python/identity/environmentcredential/troubleshoot to troubleshoot this issue.
# 11-Jul-24 15:21:01 - INFO - Request URL: 'http://169.254.169.254/metadata/identity/oauth2/token?api-version=REDACTED&resource=REDACTED'
# Request method: 'GET'
# Request headers:
#     'User-Agent': 'azsdk-python-identity/1.17.1 Python/3.11.9 (Windows-10-10.0.22631-SP0)'
# No body was attached to the request
# 11-Jul-24 15:21:01 - DEBUG - ImdsCredential.get_token failed: ManagedIdentityCredential authentication unavailable, no response from the IMDS endpoint.
# Traceback (most recent call last):
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_credentials\imds.py", line 88, in _request_token
#     self._client.request_token(*scopes, connection_timeout=1, retry_total=0)
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\managed_identity_client.py", line 131, in request_token
#     response = self._pipeline.run(request, retry_on_methods=[request.method], **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 229, in run
#     return first_node.send(pipeline_request)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   [Previous line repeated 1 more time]
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\policies\_retry.py", line 554, in send
#     raise err
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\policies\_retry.py", line 532, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   [Previous line repeated 1 more time]
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 118, in send
#     self._sender.send(request.http_request, **request.context.options),
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\transport\_requests_basic.py", line 401, in send
#     raise error
# azure.core.exceptions.ServiceRequestError: <urllib3.connection.HTTPConnection object at 0x000002A215EFCE50>: Failed to establish a new connection: [WinError 10051] A socket operation was attempted to an unreachable network
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\get_token_mixin.py", line 93, in get_token
#     token = self._request_token(
#             ^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_credentials\imds.py", line 98, in _request_token
#     raise CredentialUnavailableError(error_message) from ex
# azure.identity._exceptions.CredentialUnavailableError: ManagedIdentityCredential authentication unavailable, no response from the IMDS endpoint.
# 11-Jul-24 15:21:01 - DEBUG - ManagedIdentityCredential.get_token failed: ManagedIdentityCredential authentication unavailable, no response from the IMDS endpoint.
# Traceback (most recent call last):
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_credentials\imds.py", line 88, in _request_token
#     self._client.request_token(*scopes, connection_timeout=1, retry_total=0)
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\managed_identity_client.py", line 131, in request_token
#     response = self._pipeline.run(request, retry_on_methods=[request.method], **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 229, in run
#     return first_node.send(pipeline_request)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   [Previous line repeated 1 more time]
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\policies\_retry.py", line 554, in send
#     raise err
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\policies\_retry.py", line 532, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   [Previous line repeated 1 more time]
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 118, in send
#     self._sender.send(request.http_request, **request.context.options),
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\transport\_requests_basic.py", line 401, in send
#     raise error
# azure.core.exceptions.ServiceRequestError: <urllib3.connection.HTTPConnection object at 0x000002A215EFCE50>: Failed to establish a new connection: [WinError 10051] A socket operation was attempted to an unreachable network
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\decorators.py", line 33, in wrapper
#     token = fn(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_credentials\managed_identity.py", line 139, in get_token
#     return self._credential.get_token(*scopes, claims=claims, tenant_id=tenant_id, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\get_token_mixin.py", line 93, in get_token
#     token = self._request_token(
#             ^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_credentials\imds.py", line 98, in _request_token
#     raise CredentialUnavailableError(error_message) from ex
# azure.identity._exceptions.CredentialUnavailableError: ManagedIdentityCredential authentication unavailable, no response from the IMDS endpoint.
# 11-Jul-24 15:21:01 - DEBUG - SharedTokenCacheCredential.get_token failed: SharedTokenCacheCredential authentication unavailable. No accounts were found in the cache.
# Traceback (most recent call last):
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\decorators.py", line 33, in wrapper
#     token = fn(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_credentials\shared_cache.py", line 88, in get_token
#     return self._credential.get_token(*scopes, claims=claims, tenant_id=tenant_id, enable_cae=enable_cae, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_credentials\shared_cache.py", line 137, in get_token
#     account = self._get_account(self._username, self._tenant_id, is_cae=is_cae)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\decorators.py", line 79, in wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\shared_token_cache.py", line 205, in _get_account
#     raise CredentialUnavailableError(message=NO_ACCOUNTS)
# azure.identity._exceptions.CredentialUnavailableError: SharedTokenCacheCredential authentication unavailable. No accounts were found in the cache.
# 11-Jul-24 15:21:03 - DEBUG - AzureCliCredential.get_token succeeded
# 11-Jul-24 15:21:03 - DEBUG - [Authenticated account] Client ID: 04b07795-8ddb-461a-bbee-02f9e1bf7b46. Tenant ID: 16b3c013-d300-468d-ac64-7eda0820b6d3. User Principal Name: unavailableUpn. Object ID (user): 1e19e3c5-a350-402a-9194-1f1b3633259b
# 11-Jul-24 15:21:03 - INFO - ChainedTokenCredential acquired a token from AzureCliCredential
# 11-Jul-24 15:21:03 - DEBUG - EnvironmentCredential.get_token failed: EnvironmentCredential authentication unavailable. Environment variables are not fully configured.
# Visit https://aka.ms/azsdk/python/identity/environmentcredential/troubleshoot to troubleshoot this issue.
# Traceback (most recent call last):
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\decorators.py", line 33, in wrapper
#     token = fn(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_credentials\environment.py", line 156, in get_token
#     raise CredentialUnavailableError(message=message)
# azure.identity._exceptions.CredentialUnavailableError: EnvironmentCredential authentication unavailable. Environment variables are not fully configured.
# Visit https://aka.ms/azsdk/python/identity/environmentcredential/troubleshoot to troubleshoot this issue.
# 11-Jul-24 15:21:03 - INFO - Request URL: 'http://169.254.169.254/metadata/identity/oauth2/token?api-version=REDACTED&resource=REDACTED'
# Request method: 'GET'
# Request headers:
#     'User-Agent': 'azsdk-python-identity/1.17.1 Python/3.11.9 (Windows-10-10.0.22631-SP0)'
# No body was attached to the request
# 11-Jul-24 15:21:03 - DEBUG - ImdsCredential.get_token failed: ManagedIdentityCredential authentication unavailable, no response from the IMDS endpoint.
# Traceback (most recent call last):
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_credentials\imds.py", line 88, in _request_token
#     self._client.request_token(*scopes, connection_timeout=1, retry_total=0)
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\managed_identity_client.py", line 131, in request_token
#     response = self._pipeline.run(request, retry_on_methods=[request.method], **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 229, in run
#     return first_node.send(pipeline_request)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   [Previous line repeated 1 more time]
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\policies\_retry.py", line 554, in send
#     raise err
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\policies\_retry.py", line 532, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   [Previous line repeated 1 more time]
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 118, in send
#     self._sender.send(request.http_request, **request.context.options),
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\transport\_requests_basic.py", line 401, in send
#     raise error
# azure.core.exceptions.ServiceRequestError: <urllib3.connection.HTTPConnection object at 0x000002A215F0D110>: Failed to establish a new connection: [WinError 10051] A socket operation was attempted to an unreachable network
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\get_token_mixin.py", line 93, in get_token
#     token = self._request_token(
#             ^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_credentials\imds.py", line 98, in _request_token
#     raise CredentialUnavailableError(error_message) from ex
# azure.identity._exceptions.CredentialUnavailableError: ManagedIdentityCredential authentication unavailable, no response from the IMDS endpoint.
# 11-Jul-24 15:21:03 - DEBUG - ManagedIdentityCredential.get_token failed: ManagedIdentityCredential authentication unavailable, no response from the IMDS endpoint.
# Traceback (most recent call last):
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_credentials\imds.py", line 88, in _request_token
#     self._client.request_token(*scopes, connection_timeout=1, retry_total=0)
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\managed_identity_client.py", line 131, in request_token
#     response = self._pipeline.run(request, retry_on_methods=[request.method], **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 229, in run
#     return first_node.send(pipeline_request)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   [Previous line repeated 1 more time]
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\policies\_retry.py", line 554, in send
#     raise err
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\policies\_retry.py", line 532, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 86, in send
#     response = self.next.send(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   [Previous line repeated 1 more time]
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\_base.py", line 118, in send
#     self._sender.send(request.http_request, **request.context.options),
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\core\pipeline\transport\_requests_basic.py", line 401, in send
#     raise error
# azure.core.exceptions.ServiceRequestError: <urllib3.connection.HTTPConnection object at 0x000002A215F0D110>: Failed to establish a new connection: [WinError 10051] A socket operation was attempted to an unreachable network
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\decorators.py", line 33, in wrapper
#     token = fn(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_credentials\managed_identity.py", line 139, in get_token
#     return self._credential.get_token(*scopes, claims=claims, tenant_id=tenant_id, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\get_token_mixin.py", line 93, in get_token
#     token = self._request_token(
#             ^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_credentials\imds.py", line 98, in _request_token
#     raise CredentialUnavailableError(error_message) from ex
# azure.identity._exceptions.CredentialUnavailableError: ManagedIdentityCredential authentication unavailable, no response from the IMDS endpoint.
# 11-Jul-24 15:21:03 - DEBUG - SharedTokenCacheCredential.get_token failed: SharedTokenCacheCredential authentication unavailable. No accounts were found in the cache.
# Traceback (most recent call last):
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\decorators.py", line 33, in wrapper
#     token = fn(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_credentials\shared_cache.py", line 88, in get_token
#     return self._credential.get_token(*scopes, claims=claims, tenant_id=tenant_id, enable_cae=enable_cae, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_credentials\shared_cache.py", line 137, in get_token
#     account = self._get_account(self._username, self._tenant_id, is_cae=is_cae)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\decorators.py", line 79, in wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\shared_token_cache.py", line 205, in _get_account
#     raise CredentialUnavailableError(message=NO_ACCOUNTS)
# azure.identity._exceptions.CredentialUnavailableError: SharedTokenCacheCredential authentication unavailable. No accounts were found in the cache.
# 11-Jul-24 15:21:06 - DEBUG - AzureCliCredential.get_token succeeded
# 11-Jul-24 15:21:06 - DEBUG - [Authenticated account] Client ID: 04b07795-8ddb-461a-bbee-02f9e1bf7b46. Tenant ID: 16b3c013-d300-468d-ac64-7eda0820b6d3. User Principal Name: unavailableUpn. Object ID (user): 1e19e3c5-a350-402a-9194-1f1b3633259b
# 11-Jul-24 15:21:06 - INFO - ChainedTokenCredential acquired a token from AzureCliCredential
# 11-Jul-24 15:21:06 - DEBUG - EnvironmentCredential.get_token failed: EnvironmentCredential authentication unavailable. Environment variables are not fully configured.
# Visit https://aka.ms/azsdk/python/identity/environmentcredential/troubleshoot to troubleshoot this issue.
# Traceback (most recent call last):
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\decorators.py", line 33, in wrapper
#     token = fn(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_credentials\environment.py", line 156, in get_token
#     raise CredentialUnavailableError(message=message)
# azure.identity._exceptions.CredentialUnavailableError: EnvironmentCredential authentication unavailable. Environment variables are not fully configured.
# Visit https://aka.ms/azsdk/python/identity/environmentcredential/troubleshoot to troubleshoot this issue.
# 11-Jul-24 15:21:06 - INFO - Request URL: 'http://169.254.169.254/metadata/identity/oauth2/token?api-version=REDACTED&resource=REDACTED'
# Request method: 'GET'
# Request headers:
#     'User-Agent': 'azsdk-python-identity/1.17.1 Python/3.11.9 (Windows-10-10.0.22631-SP0)'
# No body was attached to the request
# 11-Jul-24 15:21:06 - DEBUG - ImdsCredential.get_token failed: ManagedIdentityCredential authentication unavailable, no response from the IMDS endpoint.
# Traceback (most recent call last):
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_credentials\imds.py", line 88, in _request_token
#     self._client.request_token(*scopes, connection_timeout=1, retry_total=0)
#   File "c:\repo\Personale\mlflow-export-import\.venv\Lib\site-packages\azure\identity\_internal\managed_identity_client.py", line 131, in request_token
# ...
# Request method: 'GET'
# Request headers:
#     'x-ms-range': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.20.0 Python/3.11.9 (Windows-10-10.0.22631-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'bc52bce7-3f89-11ef-a452-d03c1ffc8dce'
# No body was attached to the request
# 11-Jul-24 15:30:27 - INFO - Response status: 200
# Response headers:
#     'Date': 'Thu, 11 Jul 2024 13:30:27 GMT'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Vary': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'Content-Encoding': 'REDACTED'
# 11-Jul-24 15:30:27 - DEBUG - downloading file to c:\repo\Personale\mlflow-export-import\jupyter_notebooks\single\output\b64be052-5810-4b0f-b345-c70f81b8284f\b64be052-5810-4b0f-b345-c70f81b8284f\b64be052-5810-4b0f-b345-c70f81b8284f\e766b40d-0973-4282-b343-5308de1af237\artifacts\taxi-model/model.pkl
# 11-Jul-24 15:30:27 - INFO - Request URL: 'https://stcvz35gkdndvwydev.blob.core.windows.net/azureml/ExperimentRun/dcid.e766b40d-0973-4282-b343-5308de1af237/taxi-model/model.pkl?sv=REDACTED&sr=REDACTED&sig=REDACTED&skoid=REDACTED&sktid=REDACTED&skt=REDACTED&ske=REDACTED&sks=REDACTED&skv=REDACTED&st=REDACTED&se=REDACTED&sp=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-range': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.20.0 Python/3.11.9 (Windows-10-10.0.22631-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'bc567735-3f89-11ef-ad4e-d03c1ffc8dce'
# No body was attached to the request
# 11-Jul-24 15:30:27 - INFO - Response status: 200
# Response headers:
#     'Date': 'Thu, 11 Jul 2024 13:30:27 GMT'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Vary': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'Content-Encoding': 'REDACTED'
# 11-Jul-24 15:30:27 - DEBUG - downloading file to c:\repo\Personale\mlflow-export-import\jupyter_notebooks\single\output\b64be052-5810-4b0f-b345-c70f81b8284f\b64be052-5810-4b0f-b345-c70f81b8284f\b64be052-5810-4b0f-b345-c70f81b8284f\e766b40d-0973-4282-b343-5308de1af237\artifacts\taxi-model/python_env.yaml
# 11-Jul-24 15:30:27 - INFO - Response status: 206
# Response headers:
#     'Content-Length': '540'
#     'Content-Type': 'application/octet-stream'
#     'Content-Range': 'REDACTED'
#     'Last-Modified': 'Thu, 04 Jul 2024 06:27:48 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'ETag': '"0x8DC9BF26C5ECA2B"'
#     'Vary': 'REDACTED'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': 'ea09c9fd-601e-0075-6a96-d37c88000000'
#     'x-ms-client-request-id': 'bc32f5dc-3f89-11ef-8d28-d03c1ffc8dce'
#     'x-ms-version': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-blob-content-md5': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'Date': 'Thu, 11 Jul 2024 13:30:26 GMT'
# 11-Jul-24 15:30:27 - INFO - Request URL: 'https://westeurope.api.azureml.ms/history/v1.0/subscriptions/6e71006f-51e9-4cb5-a0d0-a2ada9895e67/resourceGroups/rg-demomlops-uc01-01dev/providers/Microsoft.MachineLearningServices/workspaces/mlw-demomlops-uc01-01dev/experiments/b64be052-5810-4b0f-b345-c70f81b8284f/runs/e766b40d-0973-4282-b343-5308de1af237/artifacts/contentinfo?path=REDACTED'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'bc5c200d-3f89-11ef-b0b6-d03c1ffc8dce'
#     'User-Agent': 'azsdk-python-mgmt-machinelearningservices/0.1.0 Python/3.11.9 (Windows-10-10.0.22631-SP0)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 11-Jul-24 15:30:27 - INFO - Request URL: 'https://westeurope.api.azureml.ms/history/v1.0/subscriptions/6e71006f-51e9-4cb5-a0d0-a2ada9895e67/resourceGroups/rg-demomlops-uc01-01dev/providers/Microsoft.MachineLearningServices/workspaces/mlw-demomlops-uc01-01dev/experiments/b64be052-5810-4b0f-b345-c70f81b8284f/runs/e766b40d-0973-4282-b343-5308de1af237/artifacts'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'bc5c6eeb-3f89-11ef-8b57-d03c1ffc8dce'
#     'User-Agent': 'azsdk-python-mgmt-machinelearningservices/0.1.0 Python/3.11.9 (Windows-10-10.0.22631-SP0)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 11-Jul-24 15:30:27 - INFO - Response status: 206
# Response headers:
#     'Content-Length': '120'
#     'Content-Type': 'application/octet-stream'
#     'Content-Range': 'REDACTED'
#     'Last-Modified': 'Thu, 04 Jul 2024 06:27:48 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'ETag': '"0x8DC9BF26C599ACA"'
#     'Vary': 'REDACTED'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '9bedaca0-401e-004d-1996-d3d848000000'
#     'x-ms-client-request-id': 'bc397b29-3f89-11ef-8753-d03c1ffc8dce'
#     'x-ms-version': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-blob-content-md5': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'Date': 'Thu, 11 Jul 2024 13:30:27 GMT'
# 11-Jul-24 15:30:27 - INFO - Request URL: 'https://stcvz35gkdndvwydev.blob.core.windows.net/azureml/ExperimentRun/dcid.e766b40d-0973-4282-b343-5308de1af237/taxi-model/python_env.yaml?sv=REDACTED&sr=REDACTED&sig=REDACTED&skoid=REDACTED&sktid=REDACTED&skt=REDACTED&ske=REDACTED&sks=REDACTED&skv=REDACTED&st=REDACTED&se=REDACTED&sp=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-range': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.20.0 Python/3.11.9 (Windows-10-10.0.22631-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'bc66c2c5-3f89-11ef-8992-d03c1ffc8dce'
# No body was attached to the request
# 11-Jul-24 15:30:27 - INFO - Response status: 206
# Response headers:
#     'Content-Length': '175'
#     'Content-Type': 'application/octet-stream'
#     'Content-Range': 'REDACTED'
#     'Last-Modified': 'Thu, 04 Jul 2024 06:27:48 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'ETag': '"0x8DC9BF26C57C652"'
#     'Vary': 'REDACTED'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': 'ae20167b-501e-0051-3c96-d38a28000000'
#     'x-ms-client-request-id': 'bc36002b-3f89-11ef-8263-d03c1ffc8dce'
#     'x-ms-version': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-blob-content-md5': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'Date': 'Thu, 11 Jul 2024 13:30:27 GMT'
# 11-Jul-24 15:30:27 - INFO - Response status: 206
# Response headers:
#     'Content-Length': '68'
#     'Content-Type': 'application/octet-stream'
#     'Content-Range': 'REDACTED'
#     'Last-Modified': 'Thu, 04 Jul 2024 06:27:48 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'ETag': '"0x8DC9BF26C594CB3"'
#     'Vary': 'REDACTED'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '9ce2e028-601e-0065-7896-d3b9e0000000'
#     'x-ms-client-request-id': 'bc52bce7-3f89-11ef-a452-d03c1ffc8dce'
#     'x-ms-version': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-blob-content-md5': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'Date': 'Thu, 11 Jul 2024 13:30:27 GMT'
# 11-Jul-24 15:30:27 - INFO - Response status: 200
# Response headers:
#     'Date': 'Thu, 11 Jul 2024 13:30:27 GMT'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Vary': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'Content-Encoding': 'REDACTED'
# 11-Jul-24 15:30:27 - DEBUG - downloading file to c:\repo\Personale\mlflow-export-import\jupyter_notebooks\single\output\b64be052-5810-4b0f-b345-c70f81b8284f\b64be052-5810-4b0f-b345-c70f81b8284f\b64be052-5810-4b0f-b345-c70f81b8284f\e766b40d-0973-4282-b343-5308de1af237\artifacts\taxi-model/requirements.txt
# 11-Jul-24 15:30:27 - INFO - Response status: 200
# Response headers:
#     'Date': 'Thu, 11 Jul 2024 13:30:27 GMT'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Vary': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'Content-Encoding': 'REDACTED'
# 11-Jul-24 15:30:27 - INFO - Request URL: 'https://stcvz35gkdndvwydev.blob.core.windows.net/azureml/ExperimentRun/dcid.e766b40d-0973-4282-b343-5308de1af237/taxi-model/requirements.txt?sv=REDACTED&sr=REDACTED&sig=REDACTED&skoid=REDACTED&sktid=REDACTED&skt=REDACTED&ske=REDACTED&sks=REDACTED&skv=REDACTED&st=REDACTED&se=REDACTED&sp=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-range': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.20.0 Python/3.11.9 (Windows-10-10.0.22631-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'bc7cf0a1-3f89-11ef-8e54-d03c1ffc8dce'
# No body was attached to the request
# 11-Jul-24 15:30:27 - INFO - Request URL: 'https://westeurope.api.azureml.ms/history/v1.0/subscriptions/6e71006f-51e9-4cb5-a0d0-a2ada9895e67/resourceGroups/rg-demomlops-uc01-01dev/providers/Microsoft.MachineLearningServices/workspaces/mlw-demomlops-uc01-01dev/experiments/b64be052-5810-4b0f-b345-c70f81b8284f/runs/e766b40d-0973-4282-b343-5308de1af237/artifacts/contentinfo?path=REDACTED'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'bc7d8c2d-3f89-11ef-a628-d03c1ffc8dce'
#     'User-Agent': 'azsdk-python-mgmt-machinelearningservices/0.1.0 Python/3.11.9 (Windows-10-10.0.22631-SP0)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 11-Jul-24 15:30:27 - INFO - Response status: 206
# Response headers:
#     'Content-Length': '22757269'
#     'Content-Type': 'application/octet-stream'
#     'Content-Range': 'REDACTED'
#     'Last-Modified': 'Thu, 04 Jul 2024 06:27:48 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'ETag': '"0x8DC9BF26C82C7BA"'
#     'Vary': 'REDACTED'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '76843be5-f01e-0005-4096-d3c57f000000'
#     'x-ms-client-request-id': 'bc567735-3f89-11ef-ad4e-d03c1ffc8dce'
#     'x-ms-version': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-blob-content-md5': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'Date': 'Thu, 11 Jul 2024 13:30:27 GMT'
# 11-Jul-24 15:30:27 - INFO - Response status: 200
# Response headers:
#     'Date': 'Thu, 11 Jul 2024 13:30:28 GMT'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Vary': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'Content-Encoding': 'REDACTED'
# 11-Jul-24 15:30:27 - DEBUG - downloading file to c:\repo\Personale\mlflow-export-import\jupyter_notebooks\single\output\b64be052-5810-4b0f-b345-c70f81b8284f\b64be052-5810-4b0f-b345-c70f81b8284f\b64be052-5810-4b0f-b345-c70f81b8284f\e766b40d-0973-4282-b343-5308de1af237\artifacts\user_logs/std_log.txt
# 11-Jul-24 15:30:27 - INFO - Response status: 206
# Response headers:
#     'Content-Length': '120'
#     'Content-Type': 'application/octet-stream'
#     'Content-Range': 'REDACTED'
#     'Last-Modified': 'Thu, 04 Jul 2024 06:27:48 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'ETag': '"0x8DC9BF26C588980"'
#     'Vary': 'REDACTED'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '534b0fa3-101e-001d-4a96-d31a18000000'
#     'x-ms-client-request-id': 'bc66c2c5-3f89-11ef-8992-d03c1ffc8dce'
#     'x-ms-version': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-blob-content-md5': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'Date': 'Thu, 11 Jul 2024 13:30:27 GMT'
# 11-Jul-24 15:30:27 - INFO - Request URL: 'https://stcvz35gkdndvwydev.blob.core.windows.net/azureml/ExperimentRun/dcid.e766b40d-0973-4282-b343-5308de1af237/user_logs/std_log.txt?sv=REDACTED&sr=REDACTED&sig=REDACTED&skoid=REDACTED&sktid=REDACTED&skt=REDACTED&ske=REDACTED&sks=REDACTED&skv=REDACTED&st=REDACTED&se=REDACTED&sp=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-range': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.20.0 Python/3.11.9 (Windows-10-10.0.22631-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'bc996841-3f89-11ef-9d99-d03c1ffc8dce'
# No body was attached to the request
# 11-Jul-24 15:30:28 - INFO - Response status: 206
# Response headers:
#     'Content-Length': '68'
#     'Content-Type': 'application/octet-stream'
#     'Content-Range': 'REDACTED'
#     'Last-Modified': 'Thu, 04 Jul 2024 06:27:48 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'ETag': '"0x8DC9BF26C599ACA"'
#     'Vary': 'REDACTED'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '5d339e8d-b01e-0059-7296-d39027000000'
#     'x-ms-client-request-id': 'bc7cf0a1-3f89-11ef-8e54-d03c1ffc8dce'
#     'x-ms-version': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-blob-content-md5': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'Date': 'Thu, 11 Jul 2024 13:30:28 GMT'
# 11-Jul-24 15:30:28 - INFO - Response status: 206
# Response headers:
#     'Content-Length': '1191'
#     'Content-Type': 'application/octet-stream'
#     'Content-Range': 'REDACTED'
#     'Last-Modified': 'Thu, 04 Jul 2024 06:27:51 GMT'
#     'Accept-Ranges': 'REDACTED'
#     'ETag': '"0x8DC9BF26E2F4FB9"'
#     'Vary': 'REDACTED'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '288b3f22-d01e-002d-1396-d3a4d7000000'
#     'x-ms-client-request-id': 'bc996841-3f89-11ef-9d99-d03c1ffc8dce'
#     'x-ms-version': 'REDACTED'
#     'x-ms-creation-time': 'REDACTED'
#     'x-ms-lease-status': 'REDACTED'
#     'x-ms-lease-state': 'REDACTED'
#     'x-ms-blob-type': 'REDACTED'
#     'Content-Disposition': 'REDACTED'
#     'x-ms-server-encrypted': 'REDACTED'
#     'Date': 'Thu, 11 Jul 2024 13:30:28 GMT'
# 11-Jul-24 15:30:29 - INFO - Exported run in 25.4s: {'run_id': 'e766b40d-0973-4282-b343-5308de1af237', 'lifecycle_stage': 'active', 'experiment_id': 'b64be052-5810-4b0f-b345-c70f81b8284f'}
# 11-Jul-24 15:30:29 - INFO - 13/14 runs succesfully exported for experiment 'dev_taxi_fare_train_dev' (ID: b64be052-5810-4b0f-b345-c70f81b8284f)
# 11-Jul-24 15:30:29 - INFO - 2/14 runs failed for experiment 'dev_taxi_fare_train_dev' (ID: b64be052-5810-4b0f-b345-c70f81b8284f)
# (13, 2)
